# %% [markdown]
# ## 1. Set up

# %% [markdown]
# ### 1 - Drive

# %% [markdown]
# 1 - Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 2 - Move to the data folder

# %%
cd "gdrive/MyDrive/Projects/1 - Numericals/Predict Future Sales/2 - Production/data"
# Out:
# /content/gdrive/MyDrive/Projects/1 - Numericals/Predict Future Sales/2 - Production/data

# %% [markdown]
# ### 2. Libraries

# %%
# Load data
import pandas as pd
import numpy as np
import io
import os
import glob

# Meta
import time

# Visualizations
import matplotlib.pyplot as plt
import seaborn as sb
from matplotlib.lines import Line2D

# Analysis
from scipy.stats import zscore

# %% [markdown]
# ## 3. Data

# %% [markdown]
# 1 - List file names

# %%
ls
# Out:
# cleaned_1.csv                                      kaggle.json
# cleaned_2.csv                                      sales_train.csv
# competitive-data-science-predict-future-sales.zip  sample_submission.csv
# item_categories.csv                                shops.csv
# items.csv                                          test.csv

# %%
# Load sales_train - with item_cnt_day
df_1 = pd.read_csv('cleaned_1.csv')

# %%
# Load sales_train - with item_cnt_month
df_2 = pd.read_csv('cleaned_2.csv')

# %% [markdown]
# ## 4. Create an OLS model

# %%
import statsmodels.api as sm

# %%
model_1 = sm.OLS(df_2['item_cnt_month'],df_2[['shop_id', 'item_id', 'date_block_num','item_price']])

# %%
results = model_1.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:         item_cnt_month   R-squared (uncentered):                   0.286
# Model:                            OLS   Adj. R-squared (uncentered):              0.286
# Method:                 Least Squares   F-statistic:                          1.499e+05
# Date:                Mon, 14 Mar 2022   Prob (F-statistic):                        0.00
# Time:                        08:29:18   Log-Likelihood:                     -3.7912e+06
# No. Observations:             1499208   AIC:                                  7.582e+06
# Df Residuals:                 1499204   BIC:                                  7.582e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...
